# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
dataset=pd.read_csv('.\clean_dataset\clean_data2.csv')

# %%
dataset
# Out:
#           director_name                           genres      actor_1_name  \
# 0         James Cameron  Action Adventure Fantasy Sci-Fi       CCH Pounder
# 1        Gore Verbinski         Action Adventure Fantasy       Johnny Depp
# 2            Sam Mendes        Action Adventure Thriller   Christoph Waltz
# 3     Christopher Nolan                  Action Thriller         Tom Hardy
# 4           Doug Walker                      Documentary       Doug Walker
# ...                 ...                              ...               ...
# 5771  Steven Spielberg               Music Crime Romance      Ansel Elgort
# 5772      Craig Brewer                            Comedy      Eddie Murphy
# 5773    Florian Zeller                             Drama   Anthony Hopkins
# 5774     Patty Jenkins          Fantasy Action Adventure         Gal Gadot
# 5775   Paul Greengrass                     Drama Western         Tom Hanks
#
#           actor_2_name          actor_3_name  \
# 0     Joel David Moore             Wes Studi
# 1        Orlando Bloom        Jack Davenport
# 2         Rory Kinnear      Stephanie Sigman
# 3       Christian Bale  Joseph Gordon-Levitt
# 4           Rob Walker               unknown
# ...                ...                   ...
# 5771     Rachel Zegler         Ariana DeBose
# 5772   Jermaine Fowler          Arsenio Hall
# 5773     Olivia Colman           Mark Gatiss
# 5774        Chris Pine          Kristen Wiig
# 5775     Helena Zengel       Neil Sandilands
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5771                                    West Side Story
# 5772                                   Coming 2 America
# 5773                                         The Father
# 5774                                  Wonder Woman 1984
# 5775                                  News of the World
#
#                                                   combo
# 0     James Cameron CCH Pounder Joel David Moore Wes...
# 1     Gore Verbinski Johnny Depp Orlando Bloom Jack ...
# 2     Sam Mendes Christoph Waltz Rory Kinnear Stepha...
# 3     Christopher Nolan Tom Hardy Christian Bale Jos...
# 4     Doug Walker Doug Walker Rob Walker unknown Doc...
# ...                                                 ...
# 5771  Steven Spielberg   Ansel Elgort  Rachel Zegler...
# 5772  Craig Brewer   Eddie Murphy  Jermaine Fowler  ...
# 5773  Florian Zeller   Anthony Hopkins  Olivia Colma...
# 5774  Patty Jenkins   Gal Gadot  Chris Pine  Kristen...
# 5775  Paul Greengrass   Tom Hanks  Helena Zengel  Ne...
#
# [5776 rows x 7 columns]

# %%
def create_similarity():
    cv=CountVectorizer()
    count_matrix=cv.fit_transform(dataset['combo'])
    similarity_score=cosine_similarity(count_matrix)
    return similarity_score

# %%
def recommendation(movie):
    movie=movie.lower()
    if movie not in dataset['movie_title'].unique():
        return("SORRY! WE COULDN'T FIND YOUR REQUEST")
    else:
        similarity_score=create_similarity()
        location=dataset.loc[dataset['movie_title']==movie].index[0]
        similar_movie=list(enumerate(similarity_score[location]))
        similar_movie=sorted(similar_movie,key=lambda x:x[1],reverse=True)
        similar_movie=similar_movie[1:11]
        recommended_movies=[]
        for movies in range(len(similar_movie)):
            m=similar_movie[movies][0]
            recommended_movies.append(dataset['movie_title'][m])
        return recommended_movies

# %%
recommendation('the notebook')
# Out:
# ['blue valentine',
#  'Song to Song',
#  'crazy, stupid, love.',
#  'hope floats',
#  'entourage\xa0           ',
#  'little black book',
#  'lars and the real girl',
#  'machine gun mccain',
#  'half nelson',
#  'all good things']

# %%
import pickle

# %%
pickle.dump(similarity_score,open('mrs.pickle','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e4c457e75806> in <module>
# ----> 1 pickle.dump(similarity_score,open('mrs.pickle','wb'))
#
# NameError: name 'similarity_score' is not defined
